# %%
# !ls
# Out:
# Untitled.ipynb            prices_round_2_day_1.csv  trades_round_2_day_1.csv
# prices_round_2_day_-1.csv trades_round_2_day_-1.csv
# prices_round_2_day_0.csv  trades_round_2_day_0.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
day0 = pd.read_csv("prices_round_2_day_0.csv", delimiter=";")
day0_SQUID = day0[day0["product"] == "SQUID_INK"]
day0_SQUID
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 5        0          0  SQUID_INK         1968            30          NaN
# 9        0        100  SQUID_INK         1969             4       1967.0
# 16       0        200  SQUID_INK         1966             1       1965.0
# 24       0        300  SQUID_INK         1965            25          NaN
# 37       0        400  SQUID_INK         1966            25          NaN
# ...    ...        ...        ...          ...           ...          ...
# 79961    0     999500  SQUID_INK         1830            28          NaN
# 79970    0     999600  SQUID_INK         1832             7       1831.0
# 79981    0     999700  SQUID_INK         1834             1       1832.0
# 79984    0     999800  SQUID_INK         1837            27          NaN
# 79993    0     999900  SQUID_INK         1838            23          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
plt.plot(day0_SQUID["timestamp"], day0_SQUID["mid_price"])
